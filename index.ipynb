# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Scrape events from a website
# * Follow links to those events to retrieve further information
# * Clean and store scraped data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
#Load the https://www.residentadvisor.net/events page in your browser.
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
#Open the inspect element feature in your browser

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import time

# %%
#explore a bit
html_page = requests.get('https://www.residentadvisor.net/events/jp/kansai') #making the request to retrieve the page
soup = BeautifulSoup(html_page.content, 'html.parser') #passing the page contents to BeautifulSoup to parse
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en,ja,es">
# <head id="_x1"><title>
# 	RA: Events in Kansai, Japan
# </title><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="en,ja,es" http-equiv="content-language"/><meta content="RA: Resident Advisor" name="Description"/><meta content="RA, residentadvisor, resident, advisor, music, ra, events, in, kansai, japan" name="Keywords"/><meta content="Resident Advisor" name="Author"/><meta content="Resident Advisor" property="og:site_name"/><meta content="712773712080127" property="fb:app_id"/><link href="/bundles/default-css?v=ATv7yC5anBBrxJoYdSr-DqUPyab_mqaaXHG0qxMzlYI1" rel="stylesheet"/>
# <meta content="app-id=981952703, app-argument=ra-guide://search" name="apple-itunes-app"/><link href="/bundles/cat-listings-css?v=qgpSmyPbylOKeJFqy2yvCrTgAsw9yQYcJtLKS_vPO6s1" rel="stylesheet"/>
# ...

# %%
#Finding the container we want
event_listings = soup.find('div', id="event-listing")

# %%
entries = event_listings.findAll('li')
print(len(entries), entries[0])
# Out:
# 156 <li><p class="eventDate date"><a href="/events.aspx?ai=66&amp;v=day&amp;mn=10&amp;yr=2019&amp;dy=1"><span>Tue, 01 Oct 2019 /</span></a></p></li>

# %%
rows = []
for entry in entries:
    date = entry.find('p', class_="eventDate date")
    event = entry.find('h1', class_="event-title")
    if event:
        details = event.text.split(' at ')
        event_name = details[0].strip()
        venue = details[1].strip()
        try:
            n_attendees = int(re.match("(\d*)", entry.find('p', class_="attending").text)[0])
        except:
            n_attendees = np.nan
        rows.append([event_name, venue, cur_date, n_attendees])
    elif date:
        cur_date = date.text
    else:
        continue
df = pd.DataFrame(rows)
df.head()
# Out:
#                     0              1                   2    3
# 0       Classic State      Club Move  Tue, 01 Oct 2019 /  2.0
# 1  Haus Holic/ 3F KEY  Giraffe Japan  Tue, 01 Oct 2019 /  1.0
# 2            梅田lovers      OWL Osaka  Tue, 01 Oct 2019 /  1.0
# 3         Blast / SEA  Kitsune Kyoto  Tue, 01 Oct 2019 /  1.0
# 4            神戸lovers          Larus  Tue, 01 Oct 2019 /  NaN

# %%
#Final function
def scrape_events(events_page_url):
    #Your code here
    response = requests.get(events_page_url)
    soup = BeautifulSoup(response.content, 'html.parser')
    entries = event_listings.findAll('li')
    rows = []
    for entry in entries:
        #Is it a date? If so, set current date.
        date = entry.find('p', class_="eventDate date")
        event = entry.find('h1', class_="event-title")
        if event:
            details = event.text.split(' at ')
            event_name = details[0].strip()
            venue = details[1].strip()
            try:
                n_attendees = int(re.match("(\d*)", entry.find('p', class_="attending").text)[0])
            except:
                n_attendees = np.nan
            rows.append([event_name, venue, cur_date, n_attendees])
        elif date:
            cur_date = date.text
        else:
            continue
    df = pd.DataFrame(rows)
    df.head()
    df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
    return df

# %%
def scrape_events(events_page_url):
    response = requests.get(events_page_url)
    soup = BeautifulSoup(response.content, "html.parser")
    events = event_listing.findAll('li')
    rows = []
    for event in events:
        date = event.find('p', class_="eventDate date")
        event_title = event.find('h1', class_="event-title")
        if event_title:
            details = event_title.text.split(' at ')
            event_name = details[0].split()
            venue = details[1].strip()
            rows.append([event_name, venue, current_date])
        elif date:
            current_date = date.text
        else:
            continue
    df = pd.DataFrame(rows)
    df.head()
    df.columns = ["Event_Name", "Venue", "Event_Date"]
    return df

# %%
scrape_events("https://www.residentadvisor.net/events/jp/kansai")
# Out:
#                                             Event_Name                  Venue  \
# 0                                        Classic State              Club Move
# 1                                   Haus Holic/ 3F KEY          Giraffe Japan
# 2                                             梅田lovers              OWL Osaka
# 3                                          Blast / SEA          Kitsune Kyoto
# 4                                             神戸lovers                  Larus
# 5                                         Angels / RED                 Cheval
# 6                                          Dive / Blue                 Cheval
# 7                                      Space / 1F Gate          Giraffe Japan
# 8                                       Jewel / 2F SUP          Giraffe Japan
# 9                                         Gemstone/ 1F                     G3
# 10                                         Bobby Brown                  Bambi
# ...

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
soup.find('a', attrs={'ga-event-action':"Next "}).attrs['href']
# Out:
# '/events/jp/kansai/week/2019-10-08'

# %%
def next_page(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    url_ext = soup.find('a', attrs={'ga-event-action':"Next "}).attrs['href'] 
    next_page_url = "https://www.residentadvisor.net" + url_ext
    return next_page_url

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
dfs = []
total_rows = 0
cur_url = "https://www.residentadvisor.net/events/jp/kansai"
while total_rows <= 1000:
    df = scrape_events(cur_url)
    dfs.append(df)
    total_rows += len(df)
    cur_url = next_page(cur_url)
    time.sleep(.2)
df = pd.concat(dfs)
df = df.iloc[:1000]
print(len(df))
df.head()
# Out:
# 1000
#            Event_Name          Venue          Event_Date  Number_of_Attendees
# 0       Classic State      Club Move  Tue, 01 Oct 2019 /                  2.0
# 1  Haus Holic/ 3F KEY  Giraffe Japan  Tue, 01 Oct 2019 /                  1.0
# 2            梅田lovers      OWL Osaka  Tue, 01 Oct 2019 /                  1.0
# 3         Blast / SEA  Kitsune Kyoto  Tue, 01 Oct 2019 /                  1.0
# 4            神戸lovers          Larus  Tue, 01 Oct 2019 /                  NaN

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully scraped a website for concert event information!
